# %% [markdown]
# ## Applied ML for baseball:

# %% [markdown]
# #### By Thomas Maxence Franco
# Submitted to the Faculty of Science in partial fulfillment of the requirements for the degree of
# #### Master of Modeling for Science and Engineering
# at the
# #### UNIVERSITAT AUTÒNOMA DE BARCELONA
# Directed by
# Tomás Manuel Margalef Burrull
# July 2024

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from itertools import combinations

# %%
file_path = "C:\\Users\\mfran\\OneDrive - UAB\\Masters\\Thesis\\v2\\tables\\finalbatdf.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                   Name  contract_years     salary        AAV  minor league  \
# 0       Randal Grichuk               1   2.000000   2.000000             0
# 1         Joc Pederson               1  12.500000  12.500000             0
# 2         Kevin Newman               1   0.946237   0.946237             0
# 3      Tucker Barnhart               2   6.500000   3.250000             0
# 4  Lourdes Gurriel Jr.               3  42.000000  14.000000             0
#
#    catcher  date new_team former_team  Age  ...  SB_3     BB%_3      K%_3  \
# 0        0  2024      ARI         LAA   32  ...   0.0  0.049541  0.209174
# 1        0  2024      ARI         SFG   32  ...   2.0  0.081081  0.243243
# 2        0  2024      ARI         CIN   30  ...   6.0  0.048736  0.074007
# 3        1  2024      ARI         LAD   33  ...   0.0  0.074742  0.257732
# 4        0  2024      ARI         ARI   30  ...   1.0  0.059150  0.188540
#
#       AVG_3     OBP_3     SLG_3  GDP_3  CS_3    H_3     OPS_3
# 0  0.240704  0.280734  0.422701   17.0   3.0  123.0  0.703435
# 1  0.237762  0.309771  0.421911    9.0   3.0  102.0  0.731683
# 2  0.226306  0.264599  0.309478    7.0   1.0  117.0  0.574076
# 3  0.247126  0.317010  0.367816    8.0   0.0   86.0  0.684826
# 4  0.276000  0.318519  0.466000    8.0   3.0  138.0  0.784519
#
# [5 rows x 61 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 61 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              276 non-null    object
#  1   contract_years    276 non-null    int64
#  2   salary            276 non-null    float64
#  3   AAV               276 non-null    float64
#  4   minor league      276 non-null    int64
#  5   catcher           276 non-null    int64
#  6   date              276 non-null    int64
#  7   new_team          276 non-null    object
#  8   former_team       276 non-null    object
#  9   Age               276 non-null    int64
#  10  WAR3              276 non-null    float64
#  11  Yrs               276 non-null    int64
#  12  career_games      276 non-null    int64
#  13  stayed_same_team  276 non-null    int64
#  14  G                 270 non-null    float64
#  15  PA                270 non-null    float64
#  16  HR                270 non-null    float64
#  17  R                 270 non-null    float64
#  18  RBI               270 non-null    float64
#  19  SB                270 non-null    float64
#  20  BB%               270 non-null    float64
#  21  K%                270 non-null    float64
#  22  AVG               270 non-null    float64
#  23  OBP               270 non-null    float64
#  24  SLG               270 non-null    float64
#  25  GDP               270 non-null    float64
#  26  CS                270 non-null    float64
#  27  H                 270 non-null    float64
#  28  OPS               270 non-null    float64
#  29  PlayerId          270 non-null    float64
#  30  MLBAMID           270 non-null    float64
#  31  G_2               255 non-null    float64
#  32  PA_2              255 non-null    float64
#  33  HR_2              255 non-null    float64
#  34  R_2               255 non-null    float64
#  35  RBI_2             255 non-null    float64
#  36  SB_2              255 non-null    float64
#  37  BB%_2             255 non-null    float64
#  38  K%_2              255 non-null    float64
#  39  AVG_2             255 non-null    float64
#  40  OBP_2             255 non-null    float64
#  41  SLG_2             255 non-null    float64
#  42  GDP_2             255 non-null    float64
#  43  CS_2              255 non-null    float64
#  44  H_2               255 non-null    float64
#  45  OPS_2             255 non-null    float64
#  46  G_3               253 non-null    float64
#  47  PA_3              253 non-null    float64
#  48  HR_3              253 non-null    float64
#  49  R_3               253 non-null    float64
#  50  RBI_3             253 non-null    float64
#  51  SB_3              253 non-null    float64
#  52  BB%_3             253 non-null    float64
#  53  K%_3              253 non-null    float64
#  54  AVG_3             253 non-null    float64
#  55  OBP_3             253 non-null    float64
#  56  SLG_3             253 non-null    float64
#  57  GDP_3             253 non-null    float64
#  58  CS_3              253 non-null    float64
#  59  H_3               253 non-null    float64
#  60  OPS_3             253 non-null    float64
# dtypes: float64(50), int64(8), object(3)
# memory usage: 131.7+ KB

# %%
df2 = df.rename(columns={'minor league': 'min_league', 'date':'year'})
df2.head()
# Out:
#                   Name  contract_years     salary        AAV  min_league  \
# 0       Randal Grichuk               1   2.000000   2.000000           0
# 1         Joc Pederson               1  12.500000  12.500000           0
# 2         Kevin Newman               1   0.946237   0.946237           0
# 3      Tucker Barnhart               2   6.500000   3.250000           0
# 4  Lourdes Gurriel Jr.               3  42.000000  14.000000           0
#
#    catcher  year new_team former_team  Age  ...  SB_3     BB%_3      K%_3  \
# 0        0  2024      ARI         LAA   32  ...   0.0  0.049541  0.209174
# 1        0  2024      ARI         SFG   32  ...   2.0  0.081081  0.243243
# 2        0  2024      ARI         CIN   30  ...   6.0  0.048736  0.074007
# 3        1  2024      ARI         LAD   33  ...   0.0  0.074742  0.257732
# 4        0  2024      ARI         ARI   30  ...   1.0  0.059150  0.188540
#
#       AVG_3     OBP_3     SLG_3  GDP_3  CS_3    H_3     OPS_3
# 0  0.240704  0.280734  0.422701   17.0   3.0  123.0  0.703435
# 1  0.237762  0.309771  0.421911    9.0   3.0  102.0  0.731683
# 2  0.226306  0.264599  0.309478    7.0   1.0  117.0  0.574076
# 3  0.247126  0.317010  0.367816    8.0   0.0   86.0  0.684826
# 4  0.276000  0.318519  0.466000    8.0   3.0  138.0  0.784519
#
# [5 rows x 61 columns]

# %% [markdown]
# The columns without a prefix '_2' or '_3' are the statistics from the last played season to that date (could be 2024,2023 or 2022). We have less missing values from those than the ones ending in _2 or _3. I chose to fill those values with the last season values to not lose data. This is still good practice as we are not making up data, just spreading a year of performance by that same player.

# %%
# Fills missing values in columns with '_2' suffix using corresponding values from columns without '_2' suffix
for col_suffix in ['G','PA', 'HR', 'R', 'RBI', 'SB', 'BB%', 'K%', 'AVG', 'OBP', 'SLG', 'GDP', 'CS', 'H', 'OPS']:
    df2[f'{col_suffix}_2'].fillna(df2[col_suffix], inplace=True)

# Fills missing values in columns with '_3' suffix using corresponding values from columns without '_3' suffix
for col_suffix in ['G','PA', 'HR', 'R', 'RBI', 'SB', 'BB%', 'K%', 'AVG', 'OBP', 'SLG', 'GDP', 'CS', 'H', 'OPS']:
    df2[f'{col_suffix}_3'].fillna(df2[col_suffix], inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 61 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              276 non-null    object
#  1   contract_years    276 non-null    int64
#  2   salary            276 non-null    float64
#  3   AAV               276 non-null    float64
#  4   min_league        276 non-null    int64
#  5   catcher           276 non-null    int64
#  6   year              276 non-null    int64
#  7   new_team          276 non-null    object
#  8   former_team       276 non-null    object
#  9   Age               276 non-null    int64
#  10  WAR3              276 non-null    float64
#  11  Yrs               276 non-null    int64
#  12  career_games      276 non-null    int64
#  13  stayed_same_team  276 non-null    int64
#  14  G                 270 non-null    float64
#  15  PA                270 non-null    float64
#  16  HR                270 non-null    float64
#  17  R                 270 non-null    float64
#  18  RBI               270 non-null    float64
#  19  SB                270 non-null    float64
#  20  BB%               270 non-null    float64
#  21  K%                270 non-null    float64
#  22  AVG               270 non-null    float64
#  23  OBP               270 non-null    float64
#  24  SLG               270 non-null    float64
#  25  GDP               270 non-null    float64
#  26  CS                270 non-null    float64
#  27  H                 270 non-null    float64
#  28  OPS               270 non-null    float64
#  29  PlayerId          270 non-null    float64
#  30  MLBAMID           270 non-null    float64
#  31  G_2               270 non-null    float64
#  32  PA_2              270 non-null    float64
#  33  HR_2              270 non-null    float64
#  34  R_2               270 non-null    float64
#  35  RBI_2             270 non-null    float64
#  36  SB_2              270 non-null    float64
#  37  BB%_2             270 non-null    float64
#  38  K%_2              270 non-null    float64
#  39  AVG_2             270 non-null    float64
#  40  OBP_2             270 non-null    float64
#  41  SLG_2             270 non-null    float64
#  42  GDP_2             270 non-null    float64
#  43  CS_2              270 non-null    float64
#  44  H_2               270 non-null    float64
#  45  OPS_2             270 non-null    float64
#  46  G_3               270 non-null    float64
#  47  PA_3              270 non-null    float64
#  48  HR_3              270 non-null    float64
#  49  R_3               270 non-null    float64
#  50  RBI_3             270 non-null    float64
#  51  SB_3              270 non-null    float64
#  52  BB%_3             270 non-null    float64
#  53  K%_3              270 non-null    float64
#  54  AVG_3             270 non-null    float64
#  55  OBP_3             270 non-null    float64
#  56  SLG_3             270 non-null    float64
#  57  GDP_3             270 non-null    float64
#  58  CS_3              270 non-null    float64
#  59  H_3               270 non-null    float64
#  60  OPS_3             270 non-null    float64
# dtypes: float64(50), int64(8), object(3)
# memory usage: 131.7+ KB

# %% [markdown]
# for those missing values, which are 6, i will drop them as we dont have any performance data and doesnt affect the size of our dataframe

# %%
df2.dropna(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 270 entries, 0 to 275
# Data columns (total 61 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              270 non-null    object
#  1   contract_years    270 non-null    int64
#  2   salary            270 non-null    float64
#  3   AAV               270 non-null    float64
#  4   min_league        270 non-null    int64
#  5   catcher           270 non-null    int64
#  6   year              270 non-null    int64
#  7   new_team          270 non-null    object
#  8   former_team       270 non-null    object
#  9   Age               270 non-null    int64
#  10  WAR3              270 non-null    float64
#  11  Yrs               270 non-null    int64
#  12  career_games      270 non-null    int64
#  13  stayed_same_team  270 non-null    int64
#  14  G                 270 non-null    float64
#  15  PA                270 non-null    float64
#  16  HR                270 non-null    float64
#  17  R                 270 non-null    float64
#  18  RBI               270 non-null    float64
#  19  SB                270 non-null    float64
#  20  BB%               270 non-null    float64
#  21  K%                270 non-null    float64
#  22  AVG               270 non-null    float64
#  23  OBP               270 non-null    float64
#  24  SLG               270 non-null    float64
#  25  GDP               270 non-null    float64
#  26  CS                270 non-null    float64
#  27  H                 270 non-null    float64
#  28  OPS               270 non-null    float64
#  29  PlayerId          270 non-null    float64
#  30  MLBAMID           270 non-null    float64
#  31  G_2               270 non-null    float64
#  32  PA_2              270 non-null    float64
#  33  HR_2              270 non-null    float64
#  34  R_2               270 non-null    float64
#  35  RBI_2             270 non-null    float64
#  36  SB_2              270 non-null    float64
#  37  BB%_2             270 non-null    float64
#  38  K%_2              270 non-null    float64
#  39  AVG_2             270 non-null    float64
#  40  OBP_2             270 non-null    float64
#  41  SLG_2             270 non-null    float64
#  42  GDP_2             270 non-null    float64
#  43  CS_2              270 non-null    float64
#  44  H_2               270 non-null    float64
#  45  OPS_2             270 non-null    float64
#  46  G_3               270 non-null    float64
#  47  PA_3              270 non-null    float64
#  48  HR_3              270 non-null    float64
#  49  R_3               270 non-null    float64
#  50  RBI_3             270 non-null    float64
#  51  SB_3              270 non-null    float64
#  52  BB%_3             270 non-null    float64
#  53  K%_3              270 non-null    float64
#  54  AVG_3             270 non-null    float64
#  55  OBP_3             270 non-null    float64
#  56  SLG_3             270 non-null    float64
#  57  GDP_3             270 non-null    float64
#  58  CS_3              270 non-null    float64
#  59  H_3               270 non-null    float64
#  60  OPS_3             270 non-null    float64
# dtypes: float64(50), int64(8), object(3)
# memory usage: 130.8+ KB

# %%
float_to_int_columns = ['G', 'PA', 'HR', 'R', 'RBI', 'SB', 'GDP', 'CS', 'H',
                        'G_2', 'PA_2', 'HR_2', 'R_2', 'RBI_2', 'SB_2', 'GDP_2', 'CS_2', 'H_2',
                        'G_3', 'PA_3', 'HR_3', 'R_3', 'RBI_3', 'SB_3', 'GDP_3', 'CS_3', 'H_3']


df2[float_to_int_columns] = df2[float_to_int_columns].astype(int)

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 270 entries, 0 to 275
# Data columns (total 61 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              270 non-null    object
#  1   contract_years    270 non-null    int64
#  2   salary            270 non-null    float64
#  3   AAV               270 non-null    float64
#  4   min_league        270 non-null    int64
#  5   catcher           270 non-null    int64
#  6   year              270 non-null    int64
#  7   new_team          270 non-null    object
#  8   former_team       270 non-null    object
#  9   Age               270 non-null    int64
#  10  WAR3              270 non-null    float64
#  11  Yrs               270 non-null    int64
#  12  career_games      270 non-null    int64
#  13  stayed_same_team  270 non-null    int64
#  14  G                 270 non-null    int32
#  15  PA                270 non-null    int32
#  16  HR                270 non-null    int32
#  17  R                 270 non-null    int32
#  18  RBI               270 non-null    int32
#  19  SB                270 non-null    int32
#  20  BB%               270 non-null    float64
#  21  K%                270 non-null    float64
#  22  AVG               270 non-null    float64
#  23  OBP               270 non-null    float64
#  24  SLG               270 non-null    float64
#  25  GDP               270 non-null    int32
#  26  CS                270 non-null    int32
#  27  H                 270 non-null    int32
#  28  OPS               270 non-null    float64
#  29  PlayerId          270 non-null    float64
#  30  MLBAMID           270 non-null    float64
#  31  G_2               270 non-null    int32
#  32  PA_2              270 non-null    int32
#  33  HR_2              270 non-null    int32
#  34  R_2               270 non-null    int32
#  35  RBI_2             270 non-null    int32
#  36  SB_2              270 non-null    int32
#  37  BB%_2             270 non-null    float64
#  38  K%_2              270 non-null    float64
#  39  AVG_2             270 non-null    float64
#  40  OBP_2             270 non-null    float64
#  41  SLG_2             270 non-null    float64
#  42  GDP_2             270 non-null    int32
#  43  CS_2              270 non-null    int32
#  44  H_2               270 non-null    int32
#  45  OPS_2             270 non-null    float64
#  46  G_3               270 non-null    int32
#  47  PA_3              270 non-null    int32
#  48  HR_3              270 non-null    int32
#  49  R_3               270 non-null    int32
#  50  RBI_3             270 non-null    int32
#  51  SB_3              270 non-null    int32
#  52  BB%_3             270 non-null    float64
#  53  K%_3              270 non-null    float64
#  54  AVG_3             270 non-null    float64
#  55  OBP_3             270 non-null    float64
#  56  SLG_3             270 non-null    float64
#  57  GDP_3             270 non-null    int32
#  58  CS_3              270 non-null    int32
#  59  H_3               270 non-null    int32
#  60  OPS_3             270 non-null    float64
# dtypes: float64(23), int32(27), int64(8), object(3)
# memory usage: 102.3+ KB

# %%
print("\nSummary Statistics:")
print(df2.describe())
# Out:
# Summary Statistics:
#        contract_years     salary         AAV  min_league     catcher  \
# count      270.000000  270.00000  270.000000  270.000000  270.000000
# mean         1.588889   19.97166    5.611029    0.359259    0.162963
# std          1.657883   64.00335    8.354012    0.480674    0.370018
# min          1.000000    0.25000    0.250000    0.000000    0.000000
# 25%          1.000000    0.72000    0.720000    0.000000    0.000000
# 50%          1.000000    1.75000    1.750000    0.000000    0.000000
# 75%          1.000000    8.87500    7.000000    1.000000    0.000000
# max         11.000000  700.00000   70.000000    1.000000    1.000000
#
#               year         Age        WAR3         Yrs  career_games  ...  \
# count   270.000000  270.000000  270.000000  270.000000    270.000000  ...
# mean   2023.011111   31.892593    2.665556    8.351852    763.977778  ...
# std       0.783109    2.949315    3.788718    3.126559    453.834198  ...
# min    2022.000000   25.000000   -1.900000    1.000000      1.000000  ...
# 25%    2022.000000   30.000000    0.000000    7.000000    484.500000  ...
# 50%    2023.000000   32.000000    1.650000    8.000000    715.000000  ...
# 75%    2024.000000   34.000000    4.300000   10.000000   1017.000000  ...
# max    2024.000000   42.000000   28.400000   21.000000   2971.000000  ...
#
#              SB_3       BB%_3        K%_3       AVG_3       OBP_3       SLG_3  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     4.666667    0.088689    0.235880    0.239926    0.313383    0.404626
# std      6.774652    0.040804    0.088325    0.054507    0.061372    0.113045
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.059846    0.188190    0.218832    0.289398    0.347409
# 50%      2.000000    0.085468    0.227583    0.249180    0.321267    0.414763
# 75%      6.000000    0.112119    0.277083    0.275601    0.343137    0.467032
# max     40.000000    0.285714    1.000000    0.350000    0.500000    0.714286
#
#             GDP_3        CS_3         H_3       OPS_3
# count  270.000000  270.000000  270.000000  270.000000
# mean     6.685185    1.744444   84.166667    0.718010
# std      5.279631    2.189334   52.622648    0.164474
# min      0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   37.250000    0.660372
# 50%      6.000000    1.000000   82.000000    0.733003
# 75%     10.000000    3.000000  124.500000    0.810373
# max     24.000000   10.000000  190.000000    1.114286
#
# [8 rows x 58 columns]

# %% [markdown]
# ### Interest Rates

# %%
df2.loc[df2['year'] == 2024, 'salary'] *= 0.994
df2.loc[df2['year'] == 2023, 'salary'] *= 1.103
df2.loc[df2['year'] == 2022, 'salary'] *= 1.1408 ## its wrong
df2.head()
# Out:
#                   Name  contract_years    salary        AAV  min_league  \
# 0       Randal Grichuk               1   1.98800   2.000000           0
# 1         Joc Pederson               1  12.42500  12.500000           0
# 2         Kevin Newman               1   0.94056   0.946237           0
# 3      Tucker Barnhart               2   6.46100   3.250000           0
# 4  Lourdes Gurriel Jr.               3  41.74800  14.000000           0
#
#    catcher  year new_team former_team  Age  ...  SB_3     BB%_3      K%_3  \
# 0        0  2024      ARI         LAA   32  ...     0  0.049541  0.209174
# 1        0  2024      ARI         SFG   32  ...     2  0.081081  0.243243
# 2        0  2024      ARI         CIN   30  ...     6  0.048736  0.074007
# 3        1  2024      ARI         LAD   33  ...     0  0.074742  0.257732
# 4        0  2024      ARI         ARI   30  ...     1  0.059150  0.188540
#
#       AVG_3     OBP_3     SLG_3  GDP_3  CS_3  H_3     OPS_3
# 0  0.240704  0.280734  0.422701     17     3  123  0.703435
# 1  0.237762  0.309771  0.421911      9     3  102  0.731683
# 2  0.226306  0.264599  0.309478      7     1  117  0.574076
# 3  0.247126  0.317010  0.367816      8     0   86  0.684826
# 4  0.276000  0.318519  0.466000      8     3  138  0.784519
#
# [5 rows x 61 columns]

# %%
df2.loc[df2['year'] == 2024, 'AAV'] *= 0.994
df2.loc[df2['year'] == 2023, 'AAV'] *= 1.103
df2.loc[df2['year'] == 2022, 'AAV'] *= 1.1408
df2.head()
# Out:
#                   Name  contract_years    salary       AAV  min_league  \
# 0       Randal Grichuk               1   1.98800   1.98800           0
# 1         Joc Pederson               1  12.42500  12.42500           0
# 2         Kevin Newman               1   0.94056   0.94056           0
# 3      Tucker Barnhart               2   6.46100   3.23050           0
# 4  Lourdes Gurriel Jr.               3  41.74800  13.91600           0
#
#    catcher  year new_team former_team  Age  ...  SB_3     BB%_3      K%_3  \
# 0        0  2024      ARI         LAA   32  ...     0  0.049541  0.209174
# 1        0  2024      ARI         SFG   32  ...     2  0.081081  0.243243
# 2        0  2024      ARI         CIN   30  ...     6  0.048736  0.074007
# 3        1  2024      ARI         LAD   33  ...     0  0.074742  0.257732
# 4        0  2024      ARI         ARI   30  ...     1  0.059150  0.188540
#
#       AVG_3     OBP_3     SLG_3  GDP_3  CS_3  H_3     OPS_3
# 0  0.240704  0.280734  0.422701     17     3  123  0.703435
# 1  0.237762  0.309771  0.421911      9     3  102  0.731683
# 2  0.226306  0.264599  0.309478      7     1  117  0.574076
# 3  0.247126  0.317010  0.367816      8     0   86  0.684826
# 4  0.276000  0.318519  0.466000      8     3  138  0.784519
#
# [5 rows x 61 columns]

# %%
df2.head()
# Out:
#                   Name  contract_years    salary       AAV  min_league  \
# 0       Randal Grichuk               1   1.98800   1.98800           0
# 1         Joc Pederson               1  12.42500  12.42500           0
# 2         Kevin Newman               1   0.94056   0.94056           0
# 3      Tucker Barnhart               2   6.46100   3.23050           0
# 4  Lourdes Gurriel Jr.               3  41.74800  13.91600           0
#
#    catcher  year new_team former_team  Age  ...  SB_3     BB%_3      K%_3  \
# 0        0  2024      ARI         LAA   32  ...     0  0.049541  0.209174
# 1        0  2024      ARI         SFG   32  ...     2  0.081081  0.243243
# 2        0  2024      ARI         CIN   30  ...     6  0.048736  0.074007
# 3        1  2024      ARI         LAD   33  ...     0  0.074742  0.257732
# 4        0  2024      ARI         ARI   30  ...     1  0.059150  0.188540
#
#       AVG_3     OBP_3     SLG_3  GDP_3  CS_3  H_3     OPS_3
# 0  0.240704  0.280734  0.422701     17     3  123  0.703435
# 1  0.237762  0.309771  0.421911      9     3  102  0.731683
# 2  0.226306  0.264599  0.309478      7     1  117  0.574076
# 3  0.247126  0.317010  0.367816      8     0   86  0.684826
# 4  0.276000  0.318519  0.466000      8     3  138  0.784519
#
# [5 rows x 61 columns]

# %% [markdown]
# drop salary and contract years as we only need AAV. MLBAMID,PlayerId, Name, new_team, former_team and year wont be need

# %%
columns_to_drop = ['salary', 'contract_years', 'MLBAMID', 'PlayerId', 'year', 'Name', 'new_team', 'former_team', 'min_league']

df3 = df2.drop(columns=columns_to_drop)

df3.head()
# Out:
#         AAV  catcher  Age  WAR3  Yrs  career_games  stayed_same_team    G  \
# 0   1.98800        0   32   2.2   10          1141                 0  118
# 1  12.42500        0   32   2.1   10          1140                 0  121
# 2   0.94056        0   30   1.1    6           505                 0   74
# 3   3.23050        1   33  -0.4   10           881                 0   47
# 4  13.91600        0   30   7.8    6           613                 1  145
#
#     PA  HR  ...  SB_3     BB%_3      K%_3     AVG_3     OBP_3     SLG_3  \
# 0  471  16  ...     0  0.049541  0.209174  0.240704  0.280734  0.422701
# 1  425  15  ...     2  0.081081  0.243243  0.237762  0.309771  0.421911
# 2  253   3  ...     6  0.048736  0.074007  0.226306  0.264599  0.309478
# 3  123   1  ...     0  0.074742  0.257732  0.247126  0.317010  0.367816
# 4  592  24  ...     1  0.059150  0.188540  0.276000  0.318519  0.466000
#
#    GDP_3  CS_3  H_3     OPS_3
# 0     17     3  123  0.703435
# 1      9     3  102  0.731683
# 2      7     1  117  0.574076
# 3      8     0   86  0.684826
# 4      8     3  138  0.784519
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Feature Selection

# %%
df3.select_dtypes(include=['number']).corr().style.background_gradient("coolwarm", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_1f324_row0_col0, #T_1f324_row1_col1, #T_1f324_row2_col2, #T_1f324_row3_col3, #T_1f324_row4_col4, #T_1f324_row5_col5, #T_1f324_row6_col6, #T_1f324_row7_col7, #T_1f324_row8_col8, #T_1f324_row9_col9, #T_1f324_row10_col10, #T_1f324_row11_col11, #T_1f324_row12_col12, #T_1f324_row13_col13, #T_1f324_row14_col14, #T_1f324_row15_col15, #T_1f324_row16_col16, #T_1f324_row17_col17, #T_1f324_row18_col18, #T_1f324_row19_col19, #T_1f324_row20_col20, #T_1f324_row21_col21, #T_1f324_row22_col22, #T_1f324_row23_col23, #T_1f324_row24_col24, #T_1f324_row25_col25, #T_1f324_row26_col26, #T_1f324_row27_col27, #T_1f324_row28_col28, #T_1f324_row29_col29, #T_1f324_row30_col30, #T_1f324_row31_col31, #T_1f324_row32_col32, #T_1f324_row33_col33, #T_1f324_row34_col34, #T_1f324_row35_col35, #T_1f324_row36_col36, #T_1f324_row37_col37, #T_1f324_row38_col38, #T_1f324_row39_col39, #T_1f324_row40_col40, #T_1f324_row41_col41, #T_1f324_row42_col42, #T_1f324_row43_col43, #T_1f324_row44_col44, #T_1f324_row45_col45, #T_1f324_row46_col46, #T_1f324_row47_col47, #T_1f324_row48_col48, #T_1f324_row49_col49, #T_1f324_row50_col50, #T_1f324_row51_col51 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f324_row0_col1, #T_1f324_row1_col0, #T_1f324_row6_col34, #T_1f324_row12_col14, #T_1f324_row14_col12, #T_1f324_row14_col40, #T_1f324_row14_col41, #T_1f324_row34_col6, #T_1f324_row34_col44, #T_1f324_row40_col14, #T_1f324_row41_col14, #T_1f324_row43_col49, #T_1f324_row44_col34, #T_1f324_row49_col43 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1f324_row0_col2, #T_1f324_row1_col33, #T_1f324_row2_col0, #T_1f324_row3_col6, #T_1f324_row6_col3, #T_1f324_row6_col9, #T_1f324_row9_col6, #T_1f324_row9_col29, #T_1f324_row17_col29, #T_1f324_row27_col44, #T_1f324_row29_col9, #T_1f324_row29_col17, #T_1f324_row33_col1, #T_1f324_row44_col27 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_1f324_row0_col3, #T_1f324_row3_col0, #T_1f324_row24_col25, #T_1f324_row25_col24, #T_1f324_row45_col46, #T_1f324_row46_col45 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_1f324_row0_col4, #T_1f324_row4_col0, #T_1f324_row8_col28, #T_1f324_row13_col20, #T_1f324_row13_col22, #T_1f324_row20_col13, #T_1f324_row22_col13, #T_1f324_row28_col8, #T_1f324_row28_col29, #T_1f324_row29_col28 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_1f324_row0_col5, #T_1f324_row0_col42, #T_1f324_row4_col9, #T_1f324_row4_col21, #T_1f324_row5_col0, #T_1f324_row9_col4, #T_1f324_row12_col45, #T_1f324_row13_col36, #T_1f324_row15_col37, #T_1f324_row19_col21, #T_1f324_row21_col4, #T_1f324_row21_col19, #T_1f324_row26_col27, #T_1f324_row27_col26, #T_1f324_row36_col13, #T_1f324_row36_col43, #T_1f324_row37_col15, #T_1f324_row42_col0, #T_1f324_row43_col36, #T_1f324_row45_col12 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_1f324_row0_col6, #T_1f324_row6_col0, #T_1f324_row14_col36, #T_1f324_row28_col34, #T_1f324_row34_col28, #T_1f324_row36_col14, #T_1f324_row37_col43, #T_1f324_row43_col37 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_1f324_row0_col7, #T_1f324_row0_col17, #T_1f324_row0_col41, #T_1f324_row5_col22, #T_1f324_row7_col0, #T_1f324_row8_col21, #T_1f324_row10_col33, #T_1f324_row17_col0, #T_1f324_row21_col8, #T_1f324_row22_col5, #T_1f324_row33_col10, #T_1f324_row37_col51, #T_1f324_row41_col0, #T_1f324_row51_col37 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_1f324_row0_col8, #T_1f324_row3_col24, #T_1f324_row5_col38, #T_1f324_row8_col0, #T_1f324_row8_col39, #T_1f324_row10_col17, #T_1f324_row10_col24, #T_1f324_row10_col41, #T_1f324_row17_col10, #T_1f324_row23_col32, #T_1f324_row24_col3, #T_1f324_row24_col10, #T_1f324_row26_col47, #T_1f324_row32_col23, #T_1f324_row36_col45, #T_1f324_row38_col5, #T_1f324_row39_col8, #T_1f324_row40_col51, #T_1f324_row41_col10, #T_1f324_row45_col36, #T_1f324_row47_col26, #T_1f324_row51_col40 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_1f324_row0_col9, #T_1f324_row3_col10, #T_1f324_row9_col0, #T_1f324_row10_col3, #T_1f324_row22_col38, #T_1f324_row26_col33, #T_1f324_row26_col39, #T_1f324_row31_col46, #T_1f324_row33_col26, #T_1f324_row38_col22, #T_1f324_row39_col26, #T_1f324_row46_col31, #T_1f324_row48_col50, #T_1f324_row50_col48 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_1f324_row0_col10, #T_1f324_row10_col0, #T_1f324_row10_col18, #T_1f324_row18_col10, #T_1f324_row22_col40, #T_1f324_row27_col34, #T_1f324_row34_col27, #T_1f324_row35_col41, #T_1f324_row38_col48, #T_1f324_row40_col22, #T_1f324_row41_col35, #T_1f324_row48_col38 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_1f324_row0_col11, #T_1f324_row3_col9, #T_1f324_row3_col11, #T_1f324_row3_col25, #T_1f324_row9_col3, #T_1f324_row11_col0, #T_1f324_row11_col3, #T_1f324_row25_col3, #T_1f324_row34_col49, #T_1f324_row49_col34 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_1f324_row0_col12, #T_1f324_row0_col51, #T_1f324_row3_col31, #T_1f324_row8_col31, #T_1f324_row10_col16, #T_1f324_row11_col19, #T_1f324_row12_col0, #T_1f324_row12_col35, #T_1f324_row12_col40, #T_1f324_row16_col10, #T_1f324_row16_col20, #T_1f324_row19_col11, #T_1f324_row19_col25, #T_1f324_row20_col16, #T_1f324_row21_col25, #T_1f324_row21_col35, #T_1f324_row21_col47, #T_1f324_row25_col19, #T_1f324_row25_col21, #T_1f324_row30_col40, #T_1f324_row31_col3, #T_1f324_row31_col8, #T_1f324_row31_col43, #T_1f324_row35_col12, #T_1f324_row35_col21, #T_1f324_row37_col46, #T_1f324_row39_col45, #T_1f324_row40_col12, #T_1f324_row40_col30, #T_1f324_row43_col31, #T_1f324_row45_col39, #T_1f324_row46_col37, #T_1f324_row47_col21, #T_1f324_row51_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_1f324_row0_col13, #T_1f324_row0_col27, #T_1f324_row1_col29, #T_1f324_row1_col44, #T_1f324_row2_col38, #T_1f324_row9_col43, #T_1f324_row11_col49, #T_1f324_row12_col24, #T_1f324_row12_col33, #T_1f324_row13_col0, #T_1f324_row15_col24, #T_1f324_row15_col34, #T_1f324_row19_col24, #T_1f324_row24_col12, #T_1f324_row24_col15, #T_1f324_row24_col19, #T_1f324_row27_col0, #T_1f324_row29_col1, #T_1f324_row30_col42, #T_1f324_row31_col34, #T_1f324_row32_col34, #T_1f324_row33_col12, #T_1f324_row34_col15, #T_1f324_row34_col31, #T_1f324_row34_col32, #T_1f324_row38_col2, #T_1f324_row42_col30, #T_1f324_row43_col9, #T_1f324_row44_col1, #T_1f324_row48_col49, #T_1f324_row49_col11, #T_1f324_row49_col48 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_1f324_row0_col14, #T_1f324_row6_col42, #T_1f324_row14_col0, #T_1f324_row14_col19, #T_1f324_row19_col14, #T_1f324_row32_col44, #T_1f324_row42_col6, #T_1f324_row44_col32, #T_1f324_row44_col49, #T_1f324_row49_col44 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_1f324_row0_col15, #T_1f324_row0_col34, #T_1f324_row3_col5, #T_1f324_row4_col11, #T_1f324_row4_col25, #T_1f324_row4_col33, #T_1f324_row5_col3, #T_1f324_row5_col45, #T_1f324_row7_col34, #T_1f324_row10_col49, #T_1f324_row11_col4, #T_1f324_row15_col0, #T_1f324_row15_col23, #T_1f324_row15_col25, #T_1f324_row15_col32, #T_1f324_row15_col46, #T_1f324_row15_col47, #T_1f324_row16_col23, #T_1f324_row23_col15, #T_1f324_row23_col16, #T_1f324_row25_col4, #T_1f324_row25_col15, #T_1f324_row32_col15, #T_1f324_row33_col4, #T_1f324_row34_col0, #T_1f324_row34_col7, #T_1f324_row41_col49, #T_1f324_row45_col5, #T_1f324_row46_col15, #T_1f324_row47_col15, #T_1f324_row49_col10, #T_1f324_row49_col41 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_1f324_row0_col16, #T_1f324_row0_col37, #T_1f324_row3_col27, #T_1f324_row4_col26, #T_1f324_row5_col17, #T_1f324_row7_col46, #T_1f324_row9_col16, #T_1f324_row16_col0, #T_1f324_row16_col9, #T_1f324_row17_col5, #T_1f324_row17_col30, #T_1f324_row18_col45, #T_1f324_row26_col4, #T_1f324_row27_col3, #T_1f324_row30_col17, #T_1f324_row31_col37, #T_1f324_row37_col0, #T_1f324_row37_col31, #T_1f324_row45_col18, #T_1f324_row46_col7, #T_1f324_row46_col48, #T_1f324_row48_col46 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_1f324_row0_col18, #T_1f324_row0_col22, #T_1f324_row0_col47, #T_1f324_row3_col37, #T_1f324_row4_col38, #T_1f324_row5

# %%
correlation_matrix = df3.corr()

correlation_with_AAV = correlation_matrix['AAV'].sort_values(ascending=False)

print("Correlation with AAV:")
print(correlation_with_AAV)

# %% [markdown]
# # Extracting predictors (X) and target variable (y) from df3
# X = df3.drop(columns=['AAV'])  # Assuming 'target_column' is the name of your target variable
# y = df3['AAV']
#
# # Define the number of folds
# k = 10
#
# # Initialize a k-fold cross-validation splitter
# kf = KFold(n_splits=k, shuffle=True)
#
# # Initialize variables to store the best subset and its corresponding error
# best_subset = None
# best_error = float('inf')
#
# # Loop through each possible subset of predictors
# for r in range(1, len(X.columns) + 1):
#     for subset in combinations(X.columns, r):
#         cv_errors = []
#         for train_index, val_index in kf.split(X):
#             X_train, X_val = X.iloc[train_index][list(subset)], X.iloc[val_index][list(subset)]
#             y_train, y_val = y.iloc[train_index], y.iloc[val_index]
#
#             # Fit model
#             model = LinearRegression()
#             model.fit(X_train, y_train)
#
#             # Predict on validation set
#             y_pred = model.predict(X_val)
#
#             # Calculate Mean Squared Prediction Error
#             mse = mean_squared_error(y_val, y_pred)
#             cv_errors.append(mse)
#
#         # Average the errors across all folds to get CV error for this subset
#         CV_error = np.mean(cv_errors)
#
#         # Update best subset if CV error is lower
#         if CV_error < best_error:
#             best_error = CV_error
#             best_subset = subset
#
# # best_subset now contains the column names of the best subset of predictors

# %% [markdown]
# # Plot MSPR results against the number of variables
# plt.plot(predictors, mspr_values, marker='o', linestyle='-')
# plt.xlabel('Number of Variables')
# plt.ylabel('Mean Squared Prediction Error (MSPR)')
# plt.title('MSPR vs. Number of Variables')
# plt.grid(True)
# plt.show()
